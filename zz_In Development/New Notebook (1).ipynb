# %%
lyr = "World Countries"

src = arcpy.da.SearchCursor(lyr, "SHAPE@")
for row in src:
    print(row)
# Out:
# (<Polygon object at 0x1e0ba62ebb0[0x1e0ba5e1060]>,)

# %%
row[0].buffer(20000)
# Out:
# <Polygon object at 0x1e0ba5e1c40[0x1e0ba5e15a0]>
